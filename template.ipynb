# %%
import utils
from copy import deepcopy
inp = utils.get_input(2025,0,"input")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 3
#       1 import utils
#       2 from copy import deepcopy
# ----> 3 inp = utils.get_input(2025,0,"input")
#
# File /media/josh/LARGEHDD/Projects/AdventOfCode/utils.py:16, in get_input(year, day, filename, split_whitespace)
#      14     filename = filename + ".txt"
#      15 curr = curr / year / day / filename
# ---> 16 with open(curr,'r') as file:
#      17     data = file.readlines()
#      18     data = [row.strip() for row in data]
#
# FileNotFoundError: [Errno 2] No such file or directory: '/media/josh/LARGEHDD/Projects/AdventOfCode/2025/0/input.txt'

# %%
p1,p2=0,0



print("p1",p1)
print("p2",p2)
# Out:
# p1 0
# p2 0
