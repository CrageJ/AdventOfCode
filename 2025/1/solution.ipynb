# %%
from viz import VideoGenerator as vg

colour = {0:(100,0,0),1:(0,100,0),2:(0,0,100),3:(100,100,100)}
generator = vg.VideoGenerator("test",colour)

# %%
for i in range(4):
    arr = [[i]]
    generator.add_frame(arr)

# %%
generator.render_gif(100)

# %%
import utils
data = utils.get_input(2025,1,"input")
print(data)
# Out:
# ['blah', 'bloh', 'gorp']
